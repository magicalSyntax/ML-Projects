# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("students_ai_usage.csv")

# %%
df.head()
# Out:
#    age education_level  study_hours_per_day uses_ai ai_tools_used  \
# 0   19         college                  1.4      No           NaN
# 1   15          school                  3.9     Yes       Copilot
# 2   15          school                  1.9     Yes       Copilot
# 3   15          school                  2.8      No           NaN
# 4   19         college                  2.7      No           NaN
#
#   purpose_of_ai  grades_before_ai  grades_after_ai  daily_screen_time_hours
# 0           NaN                62               62                        3
# 1      Research                56               61                        2
# 2      Homework                75               88                        5
# 3           NaN                55               55                        3
# 4           NaN                59               59                        3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      100 non-null    int64
#  1   education_level          100 non-null    object
#  2   study_hours_per_day      100 non-null    float64
#  3   uses_ai                  100 non-null    object
#  4   ai_tools_used            40 non-null     object
#  5   purpose_of_ai            40 non-null     object
#  6   grades_before_ai         100 non-null    int64
#  7   grades_after_ai          100 non-null    int64
#  8   daily_screen_time_hours  100 non-null    int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#               age  study_hours_per_day  grades_before_ai  grades_after_ai  \
# count  100.000000           100.000000         100.00000       100.000000
# mean    16.490000             2.987000          64.77000        68.700000
# std      1.702612             1.145713           6.16909         8.140806
# min     14.000000             1.000000          55.00000        55.000000
# 25%     15.000000             1.975000          59.00000        61.000000
# 50%     16.000000             2.800000          63.00000        69.000000
# 75%     18.000000             4.025000          70.00000        74.000000
# max     19.000000             5.000000          75.00000        89.000000
#
#        daily_screen_time_hours
# count               100.000000
# mean                  4.340000
# std                   1.793479
# min                   2.000000
# 25%                   3.000000
# 50%                   4.000000
# 75%                   6.000000
# max                   7.000000

# %%
df.shape
# Out:
# (100, 9)

# %%
df.isnull().sum()
# Out:
# age                         0
# education_level             0
# study_hours_per_day         0
# uses_ai                     0
# ai_tools_used              60
# purpose_of_ai              60
# grades_before_ai            0
# grades_after_ai             0
# daily_screen_time_hours     0
# dtype: int64

# %%
df['ai_tools_used'].value_counts()
# Out:
# ai_tools_used
# Copilot    14
# Gemini     13
# ChatGPT    13
# Name: count, dtype: int64

# %%
df['uses_ai'].value_counts()
# Out:
# uses_ai
# No     60
# Yes    40
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
def plotting(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var],kde = True)

plotting('age',1)
plotting('grades_before_ai',2)
plotting('grades_after_ai',3)
plotting('daily_screen_time_hours',4)


plt.tight_layout()

# %%
df_ai_usage = df[df['uses_ai'] == 'Yes']

# %%
df_ai_usage['education_level'].value_counts()
# Out:
# education_level
# school     20
# college    20
# Name: count, dtype: int64

# %%
def plotting(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df_ai_usage[var],kde = True)

plotting('age',1)
plotting('grades_before_ai',2)
plotting('grades_after_ai',3)
plotting('daily_screen_time_hours',4)


plt.tight_layout()

# %%
sns.countplot(x = df_ai_usage['age'], hue = df_ai_usage['daily_screen_time_hours'])
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
sns.countplot(x = df_ai_usage['grades_before_ai'], hue = df_ai_usage['daily_screen_time_hours'])
# Out:
# <Axes: xlabel='grades_before_ai', ylabel='count'>

# %%
sns.boxplot(x = 'daily_screen_time_hours', y = 'grades_before_ai',data = df_ai_usage)
# Out:
# <Axes: xlabel='daily_screen_time_hours', ylabel='grades_before_ai'>

# %%
sns.boxplot(x = 'daily_screen_time_hours', y = 'grades_after_ai',data = df_ai_usage)
# Out:
# <Axes: xlabel='daily_screen_time_hours', ylabel='grades_after_ai'>

# %%
sns.heatmap(df_ai_usage.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df_encode = pd.get_dummies(df_ai_usage)

# %%
df_encode
# Out:
#     age  study_hours_per_day  grades_before_ai  grades_after_ai  \
# 1    15                  3.9                56               61
# 2    15                  1.9                75               88
# 6    16                  3.4                72               78
# 8    19                  1.3                62               68
# 11   18                  3.5                67               76
# 17   18                  2.6                70               76
# 18   14                  1.6                74               80
# 20   18                  4.4                58               73
# 22   17                  1.6                63               76
# 27   15                  4.5                70               76
# 32   15                  1.3                62               76
# 33   14                  1.3                56               66
# 36   17                  1.8                66               77
# 37   17                  4.5                75               81
# ...

# %%
df_encode = df_encode.astype(int)

# %%
df_encode.head()
# Out:
#     age  study_hours_per_day  grades_before_ai  grades_after_ai  \
# 1    15                    3                56               61
# 2    15                    1                75               88
# 6    16                    3                72               78
# 8    19                    1                62               68
# 11   18                    3                67               76
#
#     daily_screen_time_hours  education_level_college  education_level_school  \
# 1                         2                        0                       1
# 2                         5                        0                       1
# 6                         5                        0                       1
# 8                         5                        1                       0
# 11                        7                        1                       0
#
#     uses_ai_Yes  ai_tools_used_ChatGPT  ai_tools_used_Copilot  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
numerical_cols = ['age', 'study_hours_per_day', 'grades_before_ai', 'grades_after_ai']
scaler = StandardScaler()
df_encode[numerical_cols] = scaler.fit_transform(df_encode[numerical_cols])
df_encode.head()
# Out:
#          age  study_hours_per_day  grades_before_ai  grades_after_ai  \
# 1  -0.874781             0.648622         -1.455090        -2.181381
# 2  -0.874781            -1.140680          1.509704         1.980971
# 6  -0.271484             0.648622          1.041579         0.439359
# 8   1.538407            -1.140680         -0.518839        -1.102252
# 11  0.935110             0.648622          0.261370         0.131037
#
#     daily_screen_time_hours  education_level_college  education_level_school  \
# 1                         2                        0                       1
# 2                         5                        0                       1
# 6                         5                        0                       1
# 8                         5                        1                       0
# 11                        7                        1                       0
#
#     uses_ai_Yes  ai_tools_used_ChatGPT  ai_tools_used_Copilot  \
# ...
